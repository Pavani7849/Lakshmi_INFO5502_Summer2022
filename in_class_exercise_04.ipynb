# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavani7849/Lakshmi_INFO5731_-Fall2021/blob/main/in_class_exercise_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The fourth Lab-assignment (07/26/2022 11:59'AM' - 07/29/2022 11:59PM, 50 points in total)

# %% [markdown]
# The purpose of this exercise is to understand Exploratory Data Analysis, we will practice the EDA by working on multiple datasets which have different characteristics.

# %% [markdown]
# Question 1 (10 points). Understand a text corpus for domain-specific text classification. Download the dataset from the following link: https://osf.io/8mjcy/ . Conduct EDA of the dataset from the following aspects:
#
# (1) How many categories in total?
#
# (2) How many documents under each category?

# %%
# Your answer here (code + explanation):
#
import os
from collections import defaultdict
documents = defaultdict(int)
index = 0
dir = 0

files = folders = 0
input_path = "Path to data set" #update the path to your dataset here
for _, dirnames, filenames in os.walk(input_path):
    if index == 0:
        directories = dirnames
        index += 1
    files += len(filenames)
    folders += len(dirnames)
    if len(dirnames) == 0:
        documents[directories[dir]] = len(filenames)
        dir += 1

print("There are {0} Catogeries in total".format(folders))
for key, val in documents.items():
    print("There are {1} Documents in Catogery {0}".format(key, val))
# Out:
# There are 0 Catogeries in total

# %%
#output
There are 76 Catogeries in total
There are 775 Documents in Catogery 1
There are 584 Documents in Catogery 10
There are 605 Documents in Catogery 11
There are 275 Documents in Catogery 12
There are 458 Documents in Catogery 13
There are 277 Documents in Catogery 14
There are 257 Documents in Catogery 15
There are 826 Documents in Catogery 16
There are 125 Documents in Catogery 17
There are 509 Documents in Catogery 18
There are 349 Documents in Catogery 19
There are 179 Documents in Catogery 2
There are 1129 Documents in Catogery 20
There are 735 Documents in Catogery 21
There are 284 Documents in Catogery 22
There are 179 Documents in Catogery 23
There are 628 Documents in Catogery 24
There are 244 Documents in Catogery 25
There are 754 Documents in Catogery 26
There are 77 Documents in Catogery 27
There are 315 Documents in Catogery 28
There are 213 Documents in Catogery 29
There are 184 Documents in Catogery 3
There are 881 Documents in Catogery 30
There are 516 Documents in Catogery 31
There are 118 Documents in Catogery 32
There are 272 Documents in Catogery 33
There are 786 Documents in Catogery 34
There are 68 Documents in Catogery 35
There are 889 Documents in Catogery 36
There are 74 Documents in Catogery 37
There are 503 Documents in Catogery 38
There are 261 Documents in Catogery 39
There are 231 Documents in Catogery 4
There are 510 Documents in Catogery 40
There are 1020 Documents in Catogery 41
There are 1292 Documents in Catogery 42
There are 234 Documents in Catogery 43
There are 825 Documents in Catogery 44
There are 1085 Documents in Catogery 45
There are 151 Documents in Catogery 47
There are 17 Documents in Catogery 49
There are 751 Documents in Catogery 5
There are 68 Documents in Catogery 50
There are 225 Documents in Catogery 51
There are 318 Documents in Catogery 52
There are 142 Documents in Catogery 53
There are 95 Documents in Catogery 54
There are 48 Documents in Catogery 55
There are 395 Documents in Catogery 56
There are 108 Documents in Catogery 57
There are 150 Documents in Catogery 58
There are 51 Documents in Catogery 59
There are 380 Documents in Catogery 6
There are 42 Documents in Catogery 60
There are 181 Documents in Catogery 61
There are 218 Documents in Catogery 62
There are 194 Documents in Catogery 63
There are 130 Documents in Catogery 64
There are 276 Documents in Catogery 65
There are 207 Documents in Catogery 66
There are 356 Documents in Catogery 67
There are 263 Documents in Catogery 68
There are 700 Documents in Catogery 69
There are 621 Documents in Catogery 7
There are 192 Documents in Catogery 70
There are 457 Documents in Catogery 71
There are 74 Documents in Catogery 72
There are 705 Documents in Catogery 73
There are 60 Documents in Catogery 74
There are 473 Documents in Catogery 75
There are 177 Documents in Catogery 76
There are 146 Documents in Catogery 77
There are 242 Documents in Catogery 78
There are 521 Documents in Catogery 8
There are 744 Documents in Catogery 9

# %% [markdown]
# Question 2 (40 points). Continue practicing how to do simple exploratory data analysis with Python. The dataset that has been used in this question is called Student Academics Performance Data Set, which can be downloaded at: https://github.com/suthapalliuday/INFO5502-Summer2022/blob/main/datasets/lab-assignment-04-student-performance.csv . Please conduct the following analysis:
#
# (1) Description of all the columns: for each colmun, count number of rows, number of unqiue element, the frequency of each unqiue element.
#
#
# (2)  Visualize the count for each value in the 'Study Hours' column. Note: Study Hours values comes from this >= 6 hours Good >= 4 hours Average < 2 hours Poor.
#
# (3) Using factorplot to show the relationship between numerical and categorical value. Please use figure to show relation between [Study Hours] and [End Semester Percentage]. Percentage is calculated based on the following:
#
# if percentage >=80 then Best
# If percentage >= 60 but less than 80 then Very Good
# If percentage >= 45 but less than 60 then Good
# If Percentage >= 30 but less than 45 then Pass
# If Percentage < 30 then Fail
#
# (4) Get the correlation from the data, then plug it to heatmap function and show it as following:

# %%
#upload the  file downloaded 
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-03318c23-8f48-4af5-968f-2a0ba3c83896" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-03318c23-8f48-4af5-968f-2a0ba3c83896">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving lab-assignment-04-student-performance.csv to lab-assignment-04-student-performance.csv

# %%
from pandas.core.algorithms import unique
#code

import pandas as pd
import io
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sea

#1
df = pd.read_csv(io.StringIO(uploaded['lab-assignment-04-student-performance.csv'].decode('utf-8')))
print("Description of all the columns: for each colmun, count number of rows, number of unqiue element, the frequency of each unqiue element.")
print(df.describe())

#2
df=df.dropna()
df['sh'].value_counts().plot(kind='barh')
plot.title("STUDY HOURS VISUALIZATION")
plot.xlabel("No of Students")
plot.ylabel("Study Hours")

#3
sea.catplot(x = "sh", y = "esp", data = df,kind="strip")
plot.xlabel("Study Hours")
plot.ylabel("End Semester Percentage")
plot.title("Study Hours RELATIONSHIP WITH End Semester Percentage")
plot.show()


#4
#print("Correlation Heatmap")
for cols in df.columns:
    df[cols] = df[cols].astype('category')
    catogery_cols = df.select_dtypes(['category']).columns
    df[catogery_cols] = df[catogery_cols].apply(lambda x: x.cat.codes)
corr=df.corr()
sea.heatmap(corr,annot=True)
plot.title("Correlation Heatmap")
# Out:
# Description of all the columns: for each colmun, count number of rows, number of unqiue element, the frequency of each unqiue element.
#          ge  cst   tnp   twp  iap   esp  arr         ms   ls    as  ...   fq  \
# count   131  131   131   131  131   131  131        131  131   131  ...  131
# unique    2    5     4     4    4     4    2          1    2     2  ...    6
# top       M  OBC  Good  Good   Vg  Good    N  Unmarried    V  Paid  ...   Um
# freq     72   57    59    65   63    54   78        131   92    76  ...   40
#
#          mq       fo         mo     nf       sh    ss   me     tt   atd
# count   131      131        131    131      131   131  131    131   131
# unique    6        5          5      3        3     2    4      3     3
# top      Um  Service  Housewife  Large  Average  Govt  Eng  Small  Good
# freq     52       38        115     58       59    91   62     78    56
#
# [4 rows x 22 columns]
# Text(0.5, 1.0, 'Correlation Heatmap')
